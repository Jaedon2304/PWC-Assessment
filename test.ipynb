# %%
import pandas as pd

df = pd.read_csv('simulated_trading_data.csv')
df.head()
# Out:
#          Date  Close_Price  SMA_10  SMA_20  SMA_50  SMA_100
# 0  2024-01-01   100.798240     NaN     NaN     NaN      NaN
# 1  2024-01-02   100.639712     NaN     NaN     NaN      NaN
# 2  2024-01-03   101.673049     NaN     NaN     NaN      NaN
# 3  2024-01-04   104.074575     NaN     NaN     NaN      NaN
# 4  2024-01-05   103.761543     NaN     NaN     NaN      NaN
